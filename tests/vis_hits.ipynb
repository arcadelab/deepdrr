# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
outpath = Path("output")

# load alphas.npy and facings.npy
alphas = np.load(outpath / "alphas.npy")

alphas.shape
# Out:
# (2, 60000, 32)

# %%
reshaped_alphas = alphas[1].reshape(200, 300, -1)


for i in range(32):
    plt.imshow(reshaped_alphas[:,:,i])
    plt.colorbar()
    plt.show()

# %%
# sh
